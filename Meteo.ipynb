# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
# cette ligne permet d'intégrer les graphiques au notebook
# %matplotlib inline

import matplotlib.pyplot as plt

# paramètres
plt.rcParams["figure.figsize"] = (12, 8)
plt.rcParams["font.size"] = 20

# %% [markdown]
# ## Lecture des données

# %%
# On transfert les données sur une variables datsrc + description des données

datsrc = pd.read_excel("donnees-synop-essentielles-omm.xlsx", index_col=0)
datsrc.describe()
# Out:
#        Variation_de_pression_en_3_heures  Type_de_tendance_barometrique  \
# count                        2531.000000                    2531.000000
# mean                           -0.339787                       4.414461
# std                           116.656158                       2.713473
# min                          -810.000000                       0.000000
# 25%                           -70.000000                       2.000000
# 50%                             0.000000                       5.000000
# 75%                            70.000000                       7.000000
# max                           890.000000                       8.000000
#
#        Direction _du _vent _moyen_10 mn  Vitesse_du_vent_moyen_10 mn  \
# count                       2531.000000                  2531.000000
# mean                         193.804820                     2.775109
# std                           94.954242                     1.669450
# min                            0.000000                     0.000000
# 25%                          150.000000                     1.700000
# 50%                          200.000000                     2.400000
# 75%                          270.000000                     3.400000
# max                          360.000000                    16.600000
#
#        Point_de_rosee     Humidite  Visibilite_horizontale  Temps_present  \
# count     2531.000000  2531.000000             2531.000000    2520.000000
# mean       282.904919    76.275385            35230.849467       6.041667
# std          4.966389    17.151096            18062.495445      17.829868
# min        268.750000    19.000000               50.000000       0.000000
# 25%        279.350000    65.000000            19685.000000       0.000000
# 50%        283.450000    81.000000            36310.000000       0.000000
# 75%        286.550000    90.000000            52050.000000       0.000000
# max        295.250000   100.000000            60000.000000      71.000000
#
#        Nebulosite_totale  Hauteur_de_la_base_des_nuages  Pression_station  \
# count        1390.000000                    1718.000000       2531.000000
# mean           97.549640                    1690.064028      97613.401817
# std             6.036729                    1714.961857        633.327311
# min            75.000000                      30.000000      94740.000000
# 25%           100.000000                     450.000000      97240.000000
# 50%           100.000000                    1250.000000      97640.000000
# 75%           100.000000                    2250.000000      98000.000000
# max           101.000000                    7380.000000      99310.000000
#
#        Variation_de_pression_en_24_heures  \
# count                         2505.000000
# mean                            -3.305389
# std                            461.820968
# min                          -1970.000000
# 25%                           -290.000000
# 50%                            -20.000000
# 75%                            280.000000
# max                           2220.000000
#
#        Rafale_sur_les_10_dernieres_minutes  Rafales_sur_une_periode  \
# count                          2505.000000              2531.000000
# mean                              4.529142                 5.559502
# std                               2.730535                 3.097114
# min                               0.500000                 0.800000
# 25%                               2.700000                 3.400000
# 50%                               3.800000                 4.900000
# 75%                               5.600000                 6.800000
# max                              29.900000                33.000000
#
#        Nebulosite_couche_nuageuse_1  Temperature
# count                   1705.000000  2531.000000
# mean                       4.602346    14.425405
# std                        2.792973     6.775581
# min                        0.000000    -2.600000
# 25%                        2.000000     9.700000
# 50%                        5.000000    14.200000
# 75%                        7.000000    18.700000
# max                        9.000000    38.100000

# %% [markdown]
# ## Graphiques

# %%
pd.plotting.scatter_matrix(
    datsrc[["Temperature","Point_de_rosee","Hauteur_de_la_base_des_nuages","Humidite"]], # Mettez ce que vous voulez corréler
    diagonal="kde", 
    figsize=(12, 12)
);

# %%
# tiens ce graphique à l'air intéressant, si on le regardait de plus près !

datsrc.plot.scatter(x="Temperature", y="Point_de_rosee")

# %% [markdown]
# Merveilleux, on voit que la température et la température sous laquelle la rosée se dépose naturellement sont corrélées, il va falloir expliquer le phénomène :
#
# -on obtient un graphe similaire aux approximations d'August-Roche-Magnus;
#
# -le point de rosée correspond aussi à la température à laquelle la pression partielle de vapeur d'eau est égale à sa pression de vapeur saturante;
#
# -On peut donc calculer l'humidité grâce au point de rosée.

# %%
datsrc.plot.scatter(x="Humidite", y="Temperature")

# %% [markdown]
# Nous remarquons qu'il y a une certaine corrélation entre la température et l'humidité, En effet, l'humidité augmente quand la température diminue.
